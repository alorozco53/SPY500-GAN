# %% [markdown]
# # SPY500 Synthetic Data Generation Pipeline

# %%
import os
import numpy as np
import pandas as pd

from utils.noise import generateData
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Dataset preprocessing

# %%
data = pd.read_csv('data/spy-daily.csv', index_col='Date')
adj_close_data = data['Adj Close']
adj_close_data.head()
# Out:
# Date
# 1993-01-29    27.357281
# 1993-02-01    27.551851
# 1993-02-02    27.610189
# 1993-02-03    27.902090
# 1993-02-04    28.018848
# Name: Adj Close, dtype: float64

# %%
# frame a sequence as a supervised learning problem
def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    df.columns = ['X', 'Y']
    return df

# %%
sup_data = timeseries_to_supervised(adj_close_data)
sup_data.head()
# Out:
#                     X          Y
# Date
# 1993-01-29   0.000000  27.357281
# 1993-02-01  27.357281  27.551851
# 1993-02-02  27.551851  27.610189
# 1993-02-03  27.610189  27.902090
# 1993-02-04  27.902090  28.018848

# %%
# create a differenced series
def difference(dataset, interval=1):
    assert interval >= 1
    assert isinstance(dataset, pd.DataFrame) or isinstance(dataset, pd.Series)
    return dataset.diff(interval).dropna()

# %%
# invert differenced value
def inverse_difference(history, dataset, interval=1):
    assert interval >= 1
    assert isinstance(dataset, pd.DataFrame) or isinstance(dataset, pd.Series)
    return (history - dataset).dropna()

# %%
X = adj_close_data.values
X = X.reshape(len(X), 1)
X.shape
# Out:
# (6383, 1)

# %%
# scaler example
scaler = MinMaxScaler(feature_range=(-1, 1))
scaler = scaler.fit(X)
scaled_X = scaler.transform(X)
scaled_X
# Out:
# array([[-0.99743961],
#        [-0.99593372],
#        [-0.9954822 ],
#        ...,
#        [ 0.88780018],
#        [ 0.90838763],
#        [ 0.91844905]])

# %%
# invert transform example
inverted_X = scaler.inverse_transform(scaled_X)
inverted_X
# Out:
# array([[ 27.357281],
#        [ 27.551851],
#        [ 27.610189],
#        ...,
#        [270.940002],
#        [273.600006],
#        [274.899994]])

# %%
# Split training and test set
supervised_values = sup_data.values
train_lim = int((4/5) * supervised_values.shape[0])
train, test = supervised_values[:train_lim, :], supervised_values[train_lim:, :]
train.shape, test.shape
# Out:
# ((5106, 2), (1277, 2))

# %%
# Scale training and test sets
train_scaled, test_scaled = scaler.transform(train), scaler.transform(test)

# %% [markdown]
# ## Time series regresion LSTM pipeline

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

import os

# %%
def fit_lstm(train, batch_size, nb_epoch, neurons, logdir='logs'):
    X, y = train[:, 0:-1], train[:, -1]
    X = X.reshape(X.shape[0], 1, X.shape[1])
    model = Sequential()
    model.add(LSTM(neurons, batch_input_shape=(batch_size, X.shape[1], X.shape[2]), stateful=True))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    for i in range(nb_epoch):
        model.fit(X, y, epochs=1, batch_size=batch_size, shuffle=False)
        model.reset_states()
    filename = os.path.join(logdir, 'model.h5')
    print('Saving model as {}'.format(filename))
    model.save(filename)
    return model

# %%
temp = train_scaled[:, 0:-1]
temp = temp.reshape(temp.shape[0], 1, temp.shape[1])
temp.shape
# Out:
# (5106, 1, 1)

# %%
lstm_model = fit_lstm(train_scaled, 1, 300, 4)
# Out:
# Epoch 1/1
# 5106/5106 [==============================] - 34s 7ms/step - loss: 0.0260
# Epoch 1/1
# 5106/5106 [==============================] - 34s 7ms/step - loss: 0.0019
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 0.0015
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 0.0014
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 0.0011
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 9.0827e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 8.1120e-04
# Epoch 1/1
# 5106/5106 [==============================] - 34s 7ms/step - loss: 7.4656e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 7.1392e-04
# Epoch 1/1
# 5106/5106 [==============================] - 34s 7ms/step - loss: 7.1231e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 7.1621e-04
# Epoch 1/1
# 5106/5106 [==============================] - 34s 7ms/step - loss: 7.0892e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 6.8417e-04
# Epoch 1/1
# 5106/5106 [==============================] - 34s 7ms/step - loss: 6.4746e-04
# Epoch 1/1
# 5106/5106 [==============================] - 34s 7ms/step - loss: 6.0602e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 5.6650e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 5.4295e-04
# Epoch 1/1
# 5106/5106 [==============================] - 34s 7ms/step - loss: 4.9934e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 4.9217e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 4.6138e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 4.6244e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 4.3130e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 4.3657e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 4.2008e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 6ms/step - loss: 4.0286e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 4.1197e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 4.0261e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 3.8694e-04
# Epoch 1/1
# 5106/5106 [==============================] - 34s 7ms/step - loss: 4.0110e-04
# Epoch 1/1
# 5106/5106 [==============================] - 34s 7ms/step - loss: 3.9545e-04
# Epoch 1/1
# 5106/5106 [==============================] - 34s 7ms/step - loss: 3.8570e-04
# Epoch 1/1
# 5106/5106 [==============================] - 34s 7ms/step - loss: 4.0442e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 3.9883e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 6ms/step - loss: 3.9108e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 4.2496e-04
# Epoch 1/1
# 5106/5106 [==============================] - 34s 7ms/step - loss: 4.1116e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 6ms/step - loss: 4.2075e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 6ms/step - loss: 4.3058e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 4.3962e-04
# Epoch 1/1
# 5106/5106 [==============================] - 34s 7ms/step - loss: 4.4982e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 4.6272e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 4.7993e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 5.0393e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 5.4047e-04
# Epoch 1/1
# 5106/5106 [==============================] - 33s 7ms/step - loss: 6.0436e-04
# Epoch 1/1
# 5106/5106 [==============================] - 34s 7ms/step - loss: 7.9141e-04
# Epoch 1/1
# 5106/5106 [==============================] - 34s 7ms/step - loss: 0.0012
# Epoch 1/1
#  400/5106 [=>............................] - ETA: 31s - loss: 0.0027
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-102-29d300071710> in <module>()
# ----> 1 lstm_model = fit_lstm(train_scaled, 1, 300, 4)
#
# <ipython-input-65-2446a32278d1> in fit_lstm(train, batch_size, nb_epoch, neurons)
#       7     model.compile(loss='mean_squared_error', optimizer='adam')
#       8     for i in range(nb_epoch):
# ----> 9         model.fit(X, y, epochs=1, batch_size=batch_size, shuffle=False)
#      10         model.reset_states()
#      11     return model
#
# ~/deepenv/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1040                                         initial_epoch=initial_epoch,
#    1041                                         steps_per_epoch=steps_per_epoch,
# -> 1042                                         validation_steps=validation_steps)
#    1043
#    1044     def evaluate(self, x=None, y=None,
#
# ~/deepenv/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 if not isinstance(outs, list):
#     201                     outs = [outs]
#
# ~/deepenv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2659                 return self._legacy_call(inputs)
#    2660
# -> 2661             return self._call(inputs)
#    2662         else:
#    2663             if py_any(is_tensor(x) for x in inputs):
#
# ~/deepenv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2629                                 symbol_vals,
#    2630                                 session)
# -> 2631         fetched = self._callable_fn(*array_vals)
#    2632         return fetched[:len(self.outputs)]
#    2633
#
# ~/deepenv/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args)
#    1449         if self._session._created_with_new_api:
#    1450           return tf_session.TF_SessionRunCallable(
# -> 1451               self._session._session, self._handle, args, status, None)
#    1452         else:
#    1453           return tf_session.TF_DeprecatedSessionRunCallable(
#
# KeyboardInterrupt:

# %%
train_scaled[:, 0:-1].reshape(train_scaled[:, 0:-1].shape[0], 1, train_scaled[:, 0:-1].shape[1]).shape
# Out:
# (5106, 1, 1)

# %% [markdown]
# ## Predicting using the LSTM

# %%
from keras.models import load_model

import numpy as np

# %%
model = load_model('logs/model.h5')

# %%
# forecast the entire training dataset to build up state for forecasting
train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
model.predict(train_reshaped, batch_size=1)
# Out:
# array([[-0.9097316 ],
#        [-0.9457605 ],
#        [-1.0179694 ],
#        ...,
#        [ 0.96749943],
#        [ 0.97240335],
#        [ 0.9806607 ]], dtype=float32)

# %%
# inverse scaling for a forecasted value
def invert_scale(scaler, X, value):
    new_row = [x for x in X] + [value]
    array = np.array(new_row)
    array = array.reshape(1, len(array))
    inverted = scaler.inverse_transform(array)
    return inverted[0, -1]

# make a one-step forecast
def forecast_lstm(model, batch_size, X):
    X = X.reshape(1, 1, len(X))
    yhat = model.predict(X, batch_size=batch_size)
    return yhat[0,0]

# invert differenced value
def inverse_difference(history, yhat, interval=1):
    return yhat + history[-interval]

# %%
# walk-forward validation on the test data
predictions = list()
for i in range(len(test_scaled)):
    # make one-step forecast
    X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
    yhat = forecast_lstm(model, 1, X)
    # invert scaling
    yhat = invert_scale(scaler, X, yhat)
    # invert differencing
    yhat = inverse_difference(adj_close_data.values, yhat, len(test_scaled)+1-i)
    # store forecast
    predictions.append(yhat)
    expected = adj_close_data.values[len(train) + i + 1]
    print('Time_value=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
# Out:
# Time_value=1, Predicted=319.561291, Expected=147.884644
# Time_value=2, Predicted=304.731228, Expected=148.002274
# Time_value=3, Predicted=302.855367, Expected=149.531723
# Time_value=4, Predicted=302.457978, Expected=150.337158
# Time_value=5, Predicted=304.996275, Expected=149.631256
# Time_value=6, Predicted=306.490859, Expected=151.079254
# Time_value=7, Predicted=305.269981, Expected=151.070190
# Time_value=8, Predicted=307.733638, Expected=151.287399
# Time_value=9, Predicted=307.827245, Expected=150.165207
# Time_value=10, Predicted=308.195120, Expected=149.730835
# Time_value=11, Predicted=306.215920, Expected=149.604111
# Time_value=12, Predicted=305.331609, Expected=150.500061
# Time_value=13, Predicted=305.061427, Expected=149.522690
# Time_value=14, Predicted=306.644747, Expected=150.074753
# Time_value=15, Predicted=304.981187, Expected=147.920853
# Time_value=16, Predicted=305.876593, Expected=148.735321
# Time_value=17, Predicted=302.055455, Expected=148.020416
# Time_value=18, Predicted=303.335874, Expected=145.947968
# Time_value=19, Predicted=302.119270, Expected=147.269257
# Time_value=20, Predicted=298.284242, Expected=149.142624
# Time_value=21, Predicted=300.527512, Expected=149.142624
# Time_value=22, Predicted=304.032311, Expected=147.604111
# Time_value=23, Predicted=304.183308, Expected=146.382355
# Time_value=24, Predicted=301.389530, Expected=148.608643
# Time_value=25, Predicted=299.025231, Expected=147.676483
# Time_value=26, Predicted=302.977595, Expected=148.816803
# Time_value=27, Predicted=301.480255, Expected=149.993271
# Time_value=28, Predicted=303.461066, Expected=147.920853
# Time_value=29, Predicted=305.665123, Expected=144.255630
# Time_value=30, Predicted=302.026648, Expected=144.718719
# Time_value=31, Predicted=295.126077, Expected=142.890045
# Time_value=32, Predicted=295.696279, Expected=144.263824
# Time_value=33, Predicted=292.355137, Expected=145.692184
# Time_value=34, Predicted=294.796508, Expected=146.547394
# Time_value=35, Predicted=297.557547, Expected=145.946899
# Time_value=36, Predicted=299.224211, Expected=146.802094
# Time_value=37, Predicted=298.162740, Expected=146.665665
# Time_value=38, Predicted=299.671574, Expected=146.729324
# Time_value=39, Predicted=299.483528, Expected=148.312286
# Time_value=40, Predicted=299.583914, Expected=149.158432
# Time_value=41, Predicted=302.471965, Expected=150.231949
# Time_value=42, Predicted=304.124576, Expected=150.286560
# Time_value=43, Predicted=306.110122, Expected=152.333588
# Time_value=44, Predicted=306.289271, Expected=152.397247
# Time_value=45, Predicted=309.913927, Expected=152.979492
# Time_value=46, Predicted=310.204981, Expected=152.406311
# Time_value=47, Predicted=311.229885, Expected=152.797546
# Time_value=48, Predicted=310.279564, Expected=153.634521
# Time_value=49, Predicted=310.914532, Expected=153.907486
# Time_value=50, Predicted=312.412360, Expected=154.207718
# Time_value=51, Predicted=312.969981, Expected=153.880188
# Time_value=52, Predicted=313.520325, Expected=153.316132
# Time_value=53, Predicted=312.985660, Expected=153.689133
# Time_value=54, Predicted=311.978829, Expected=153.852905
# Time_value=55, Predicted=312.573351, Expected=153.379807
# Time_value=56, Predicted=312.894549, Expected=153.379807
# Time_value=57, Predicted=312.094272, Expected=153.488983
# Time_value=58, Predicted=312.050489, Expected=155.263062
# Time_value=59, Predicted=312.239584, Expected=155.526932
# Time_value=60, Predicted=315.307909, Expected=155.299438
# Time_value=61, Predicted=315.934418, Expected=154.416977
# Time_value=62, Predicted=315.578520, Expected=153.916580
# Time_value=63, Predicted=314.042219, Expected=154.480667
# Time_value=64, Predicted=313.090890, Expected=154.034836
# Time_value=65, Predicted=314.011950, Expected=153.852905
# Time_value=66, Predicted=313.299707, Expected=154.307831
# Time_value=67, Predicted=312.945215, Expected=153.516281
# Time_value=68, Predicted=313.710969, Expected=151.369186
# Time_value=69, Predicted=312.387402, Expected=150.868820
# Time_value=70, Predicted=308.562283, Expected=149.904480
# Time_value=71, Predicted=307.470068, Expected=150.641388
# Time_value=72, Predicted=305.709041, Expected=149.713364
# Time_value=73, Predicted=306.929223, Expected=151.078064
# Time_value=74, Predicted=305.346236, Expected=151.587555
# Time_value=75, Predicted=307.683690, Expected=151.023468
# Time_value=76, Predicted=308.702670, Expected=148.594345
# Time_value=77, Predicted=307.749866, Expected=149.122055
# Time_value=78, Predicted=303.360287, Expected=149.358582
# Time_value=79, Predicted=304.087248, Expected=148.885513
# Time_value=80, Predicted=304.561013, Expected=149.558746
# Time_value=81, Predicted=303.735594, Expected=150.796051
# Time_value=82, Predicted=304.900388, Expected=150.987122
# Time_value=83, Predicted=307.161811, Expected=151.059875
# Time_value=84, Predicted=307.606032, Expected=152.506378
# Time_value=85, Predicted=307.746630, Expected=153.634521
# Time_value=86, Predicted=310.296681, Expected=154.116745
# Time_value=87, Predicted=312.395274, Expected=153.707321
# Time_value=88, Predicted=313.337099, Expected=154.053070
# Time_value=89, Predicted=312.674043, Expected=154.944611
# Time_value=90, Predicted=313.234292, Expected=155.636063
# Time_value=91, Predicted=314.804686, Expected=157.437439
# Time_value=92, Predicted=316.080009, Expected=157.173599
# Time_value=93, Predicted=319.208132, Expected=156.074661
# Time_value=94, Predicted=318.951218, Expected=155.352417
# Time_value=95, Predicted=317.075897, Expected=154.986740
# Time_value=96, Predicted=315.734336, Expected=154.538788
# Time_value=97, Predicted=315.032638, Expected=155.133026
# Time_value=98, Predicted=314.227317, Expected=154.419937
# Time_value=99, Predicted=315.202382, Expected=153.597168
# Time_value=100, Predicted=314.038454, Expected=154.813034
# Time_value=101, Predicted=312.550987, Expected=154.666763
# Time_value=102, Predicted=314.560502, Expected=153.240601
# Time_value=103, Predicted=314.426399, Expected=154.401627
# Time_value=104, Predicted=311.954216, Expected=153.066910
# Time_value=105, Predicted=313.817913, Expected=151.284210
# Time_value=106, Predicted=311.617267, Expected=151.393875
# Time_value=107, Predicted=308.372275, Expected=154.657639
# Time_value=108, Predicted=308.388787, Expected=155.654144
# Time_value=109, Predicted=314.072434, Expected=156.275818
# Time_value=110, Predicted=316.095534, Expected=155.142181
# Time_value=111, Predicted=317.259961, Expected=157.308868
# Time_value=112, Predicted=315.388331, Expected=158.360184
# Time_value=113, Predicted=318.952784, Expected=159.429840
# Time_value=114, Predicted=320.930847, Expected=159.438965
# Time_value=115, Predicted=322.832181, Expected=160.362335
# Time_value=116, Predicted=322.970473, Expected=159.594376
# Time_value=117, Predicted=324.503519, Expected=160.124619
# Time_value=118, Predicted=323.343092, Expected=160.856018
# Time_value=119, Predicted=324.145348, Expected=161.111984
# Time_value=120, Predicted=325.397936, Expected=161.971359
# Time_value=121, Predicted=325.902689, Expected=161.166824
# Time_value=122, Predicted=327.336518, Expected=160.709732
# Time_value=123, Predicted=326.132847, Expected=161.093735
# Time_value=124, Predicted=325.312058, Expected=161.660507
# Time_value=125, Predicted=325.882618, Expected=161.148544
# Time_value=126, Predicted=326.840879, Expected=161.971359
# Time_value=127, Predicted=326.077718, Expected=159.923508
# Time_value=128, Predicted=327.363100, Expected=162.081085
# Time_value=129, Predicted=324.115524, Expected=162.108505
# Time_value=130, Predicted=327.410121, Expected=161.779373
# Time_value=131, Predicted=327.671770, Expected=163.077545
# Time_value=132, Predicted=327.165210, Expected=163.891174
# Time_value=133, Predicted=329.221866, Expected=164.604309
# Time_value=134, Predicted=330.661328, Expected=164.028336
# Time_value=135, Predicted=331.899453, Expected=163.671799
# Time_value=136, Predicted=331.082786, Expected=163.159836
# Time_value=137, Predicted=330.465014, Expected=164.476273
# Time_value=138, Predicted=329.604625, Expected=165.299072
# Time_value=139, Predicted=331.634633, Expected=165.134521
# Time_value=140, Predicted=333.072896, Expected=165.180222
# Time_value=141, Predicted=332.926000, Expected=165.582504
# Time_value=142, Predicted=332.995763, Expected=165.472778
# Time_value=143, Predicted=333.633591, Expected=165.043106
# Time_value=144, Predicted=333.509695, Expected=164.330032
# Time_value=145, Predicted=332.830589, Expected=164.311707
# Time_value=146, Predicted=331.658353, Expected=163.589508
# Time_value=147, Predicted=331.542570, Expected=165.417953
# Time_value=148, Predicted=330.383817, Expected=165.838455
# Time_value=149, Predicted=333.186320, Expected=165.244247
# Time_value=150, Predicted=334.040747, Expected=163.388351
# Time_value=151, Predicted=333.183022, Expected=162.848984
# Time_value=152, Predicted=330.192366, Expected=162.830704
# Time_value=153, Predicted=329.113054, Expected=163.845490
# Time_value=154, Predicted=328.994594, Expected=163.324341
# Time_value=155, Predicted=330.596974, Expected=166.112747
# Time_value=156, Predicted=329.878309, Expected=165.920746
# Time_value=157, Predicted=334.228352, Expected=166.886108
# Time_value=158, Predicted=334.239166, Expected=167.777695
# Time_value=159, Predicted=335.758585, Expected=168.145401
# Time_value=160, Predicted=337.250171, Expected=169.000244
# Time_value=161, Predicted=337.934047, Expected=168.991043
# Time_value=162, Predicted=339.300928, Expected=168.963486
# Time_value=163, Predicted=339.398041, Expected=169.763153
# Time_value=164, Predicted=339.374948, Expected=168.136200
# Time_value=165, Predicted=340.589346, Expected=168.108597
# Time_value=166, Predicted=338.212268, Expected=167.621475
# Time_value=167, Predicted=337.998338, Expected=168.650955
# Time_value=168, Predicted=337.224428, Expected=168.687714
# Time_value=169, Predicted=338.737499, Expected=168.798050
# Time_value=170, Predicted=338.902791, Expected=169.257614
# Time_value=171, Predicted=339.091117, Expected=167.005615
# Time_value=172, Predicted=339.806285, Expected=168.825577
# Time_value=173, Predicted=336.418015, Expected=169.735596
# Time_value=174, Predicted=338.955003, Expected=169.514984
# Time_value=175, Predicted=340.506630, Expected=168.798050
# Time_value=176, Predicted=340.302060, Expected=169.294373
# Time_value=177, Predicted=339.212176, Expected=169.404663
# Time_value=178, Predicted=339.884120, Expected=168.016678
# Time_value=179, Predicted=340.096174, Expected=164.431885
# Time_value=180, Predicted=338.003056, Expected=163.623032
# Time_value=181, Predicted=332.278717, Expected=164.597397
# Time_value=182, Predicted=330.558676, Expected=163.016373
# Time_value=183, Predicted=331.940737, Expected=164.744446
# Time_value=184, Predicted=329.514873, Expected=163.779282
# Time_value=185, Predicted=332.080284, Expected=160.093399
# Time_value=186, Predicted=330.725035, Expected=161.214783
# Time_value=187, Predicted=324.695257, Expected=161.012573
# Time_value=188, Predicted=326.090094, Expected=163.135895
# Time_value=189, Predicted=325.834158, Expected=165.158081
# Time_value=190, Predicted=329.234396, Expected=165.461380
# Time_value=191, Predicted=332.671959, Expected=167.272202
# Time_value=192, Predicted=333.400284, Expected=167.354904
# Time_value=193, Predicted=336.284444, Expected=168.218933
# Time_value=194, Predicted=336.629382, Expected=169.147324
# Time_value=195, Predicted=337.998558, Expected=169.349564
# Time_value=196, Predicted=339.523485, Expected=168.228134
# Time_value=197, Predicted=339.956245, Expected=169.220856
# Time_value=198, Predicted=338.295497, Expected=169.027817
# Time_value=199, Predicted=339.688823, Expected=169.965378
# Time_value=200, Predicted=339.495352, Expected=169.901031
# Time_value=201, Predicted=340.907209, Expected=169.910233
# Time_value=202, Predicted=340.920391, Expected=170.801804
# Time_value=203, Predicted=340.945800, Expected=171.233856
# Time_value=204, Predicted=342.289728, Expected=170.029724
# Time_value=205, Predicted=343.039909, Expected=172.419586
# Time_value=206, Predicted=341.305941, Expected=172.575836
# Time_value=207, Predicted=344.739902, Expected=172.971085
# Time_value=208, Predicted=345.227097, Expected=173.044617
# Time_value=209, Predicted=345.869930, Expected=172.952744
# Time_value=210, Predicted=346.039149, Expected=172.097870
# Time_value=211, Predicted=345.926346, Expected=172.143814
# Time_value=212, Predicted=344.663833, Expected=170.213516
# Time_value=213, Predicted=344.633422, Expected=169.735596
# Time_value=214, Predicted=341.748722, Expected=171.270630
# Time_value=215, Predicted=340.801950, Expected=172.493118
# Time_value=216, Predicted=343.006153, Expected=171.573944
# Time_value=217, Predicted=344.973481, Expected=172.575836
# Time_value=218, Predicted=343.779925, Expected=171.906128
# Time_value=219, Predicted=345.184977, Expected=171.195251
# Time_value=220, Predicted=344.301870, Expected=172.007690
# Time_value=221, Predicted=343.187055, Expected=170.770554
# Time_value=222, Predicted=344.301467, Expected=170.410522
# Time_value=223, Predicted=342.540327, Expected=171.250610
# Time_value=224, Predicted=341.870064, Expected=172.653931
# Time_value=225, Predicted=343.061516, Expected=173.798752
# Time_value=226, Predicted=345.222076, Expected=174.380432
# Time_value=227, Predicted=347.072346, Expected=174.149597
# Time_value=228, Predicted=348.080910, Expected=172.090790
# Time_value=229, Predicted=347.846101, Expected=170.188934
# Time_value=230, Predicted=344.828112, Expected=170.890594
# Time_value=231, Predicted=341.759974, Expected=172.727829
# Time_value=232, Predicted=342.546392, Expected=169.099533
# Time_value=233, Predicted=345.299718, Expected=167.576172
# Time_value=234, Predicted=340.098697, Expected=168.896393
# Time_value=235, Predicted=337.389500, Expected=170.059647
# Time_value=236, Predicted=339.165225, Expected=171.841507
# Time_value=237, Predicted=341.030947, Expected=172.081528
# Time_value=238, Predicted=343.837019, Expected=172.681641
# Time_value=239, Predicted=344.421276, Expected=173.466370
# Time_value=240, Predicted=345.374301, Expected=173.060196
# Time_value=241, Predicted=346.609026, Expected=173.411026
# Time_value=242, Predicted=346.122364, Expected=171.989227
# Time_value=243, Predicted=346.610749, Expected=172.533951
# Time_value=244, Predicted=344.560597, Expected=173.337128
# Time_value=245, Predicted=345.207128, Expected=173.854141
# Time_value=246, Predicted=346.421738, Expected=173.872650
# Time_value=247, Predicted=347.273015, Expected=173.623352
# Time_value=248, Predicted=347.377981, Expected=173.955719
# Time_value=249, Predicted=347.033543, Expected=172.441605
# Time_value=250, Predicted=347.493896, Expected=173.457153
# Time_value=251, Predicted=345.314336, Expected=173.272522
# Time_value=252, Predicted=346.634203, Expected=173.531052
# Time_value=253, Predicted=346.452027, Expected=175.220535
# Time_value=254, Predicted=346.821667, Expected=175.377518
# Time_value=255, Predicted=349.297959, Expected=174.546600
# Time_value=256, Predicted=349.722549, Expected=173.014008
# Time_value=257, Predicted=348.582466, Expected=173.614136
# Time_value=258, Predicted=346.271993, Expected=174.251144
# Time_value=259, Predicted=346.957584, Expected=173.152527
# Time_value=260, Predicted=347.916587, Expected=174.611176
# Time_value=261, Predicted=346.393066, Expected=175.035904
# Time_value=262, Predicted=348.401502, Expected=175.737579
# Time_value=263, Predicted=349.162071, Expected=176.817749
# Time_value=264, Predicted=350.243989, Expected=176.688522
# Time_value=265, Predicted=351.879231, Expected=177.602493
# Time_value=266, Predicted=351.839744, Expected=177.888672
# Time_value=267, Predicted=353.147601, Expected=178.091812
# Time_value=268, Predicted=353.660297, Expected=177.999512
# Time_value=269, Predicted=354.001698, Expected=178.359558
# Time_value=270, Predicted=353.910183, Expected=179.522812
# Time_value=271, Predicted=354.413781, Expected=180.381439
# Time_value=272, Predicted=356.073182, Expected=180.566055
# Time_value=273, Predicted=357.395903, Expected=180.584549
# Time_value=274, Predicted=357.775752, Expected=179.956741
# Time_value=275, Predicted=357.852781, Expected=178.682678
# Time_value=276, Predicted=357.007982, Expected=179.227371
# Time_value=277, Predicted=355.180690, Expected=179.375092
# Time_value=278, Predicted=355.781428, Expected=179.873642
# Time_value=279, Predicted=356.012913, Expected=181.193878
# Time_value=280, Predicted=356.720707, Expected=181.396973
# Time_value=281, Predicted=358.589463, Expected=181.764969
# Time_value=282, Predicted=359.024439, Expected=181.709335
# Time_value=283, Predicted=359.582880, Expected=180.614670
# Time_value=284, Predicted=359.564636, Expected=181.431015
# Time_value=285, Predicted=358.083161, Expected=181.301147
# Time_value=286, Predicted=359.079656, Expected=181.653671
# Time_value=287, Predicted=358.967637, Expected=181.560852
# Time_value=288, Predicted=359.444820, Expected=182.776169
# Time_value=289, Predicted=359.358352, Expected=182.961639
# Time_value=290, Predicted=360.998148, Expected=183.861450
# Time_value=291, Predicted=361.379298, Expected=183.221405
# Time_value=292, Predicted=362.631632, Expected=182.043274
# Time_value=293, Predicted=361.889391, Expected=182.859589
# Time_value=294, Predicted=360.266203, Expected=182.136047
# Time_value=295, Predicted=361.230563, Expected=182.386490
# Time_value=296, Predicted=360.314365, Expected=183.304871
# Time_value=297, Predicted=360.584219, Expected=182.961639
# Time_value=298, Predicted=361.828772, Expected=183.638824
# Time_value=299, Predicted=361.469707, Expected=181.551651
# Time_value=300, Predicted=362.361213, Expected=183.406921
# Time_value=301, Predicted=359.628126, Expected=183.063690
# Time_value=302, Predicted=361.914946, Expected=183.861450
# Time_value=303, Predicted=361.609500, Expected=184.269623
# Time_value=304, Predicted=362.669050, Expected=184.278900
# Time_value=305, Predicted=363.297404, Expected=183.416229
# Time_value=306, Predicted=363.373813, Expected=183.490448
# Time_value=307, Predicted=362.245760, Expected=182.701904
# Time_value=308, Predicted=362.258931, Expected=182.729736
# Time_value=309, Predicted=361.192498, Expected=179.121124
# Time_value=310, Predicted=361.140504, Expected=178.573837
# Time_value=311, Predicted=356.203238, Expected=179.863281
# Time_value=312, Predicted=355.033229, Expected=178.119293
# Time_value=313, Predicted=356.665872, Expected=178.174973
# Time_value=314, Predicted=354.346026, Expected=177.210159
# Time_value=315, Predicted=354.243797, Expected=179.260300
# Time_value=316, Predicted=352.856722, Expected=179.779800
# Time_value=317, Predicted=355.602261, Expected=179.529358
# Time_value=318, Predicted=356.522805, Expected=180.744537
# Time_value=319, Predicted=356.274566, Expected=181.597992
# Time_value=320, Predicted=357.941836, Expected=181.560852
# Time_value=321, Predicted=359.240362, Expected=183.082291
# Time_value=322, Predicted=359.313906, Expected=184.037735
# Time_value=323, Predicted=361.392707, Expected=184.529373
# Time_value=324, Predicted=362.840748, Expected=185.067413
# Time_value=325, Predicted=363.635806, Expected=184.779861
# Time_value=326, Predicted=364.435751, Expected=185.716797
# Time_value=327, Predicted=364.139689, Expected=185.837372
# Time_value=328, Predicted=365.363275, Expected=185.763153
# Time_value=329, Predicted=365.619900, Expected=185.661118
# Time_value=330, Predicted=365.560852, Expected=186.189926
# Time_value=331, Predicted=365.432091, Expected=186.097122
# Time_value=332, Predicted=366.114459, Expected=185.995071
# Time_value=333, Predicted=366.047135, Expected=185.726105
# Time_value=334, Predicted=365.918221, Expected=186.560974
# Time_value=335, Predicted=365.559127, Expected=186.078583
# Time_value=336, Predicted=366.617085, Expected=184.900497
# Time_value=337, Predicted=366.068556, Expected=185.596191
# Time_value=338, Predicted=364.495791, Expected=185.809540
# Time_value=339, Predicted=365.279764, Expected=184.724182
# Time_value=340, Predicted=365.599160, Expected=184.585068
# Time_value=341, Predicted=364.204392, Expected=185.976517
# Time_value=342, Predicted=363.914634, Expected=186.227020
# Time_value=343, Predicted=365.700913, Expected=187.219559
# Time_value=344, Predicted=366.159674, Expected=187.051071
# Time_value=345, Predicted=367.503167, Expected=185.606476
# Time_value=346, Predicted=367.403352, Expected=184.543991
# Time_value=347, Predicted=365.540671, Expected=185.988602
# Time_value=348, Predicted=364.002299, Expected=182.987579
# Time_value=349, Predicted=365.751892, Expected=184.441483
# Time_value=350, Predicted=361.900881, Expected=184.105988
# Time_value=351, Predicted=363.538988, Expected=183.621353
# Time_value=352, Predicted=363.180446, Expected=181.132935
# Time_value=353, Predicted=362.514891, Expected=181.160889
# Time_value=354, Predicted=359.109814, Expected=183.155334
# Time_value=355, Predicted=358.860685, Expected=182.940979
# Time_value=356, Predicted=361.488206, Expected=180.117020
# Time_value=357, Predicted=361.394680, Expected=183.267166
# Time_value=358, Predicted=357.583539, Expected=179.632416
# Time_value=359, Predicted=361.549696, Expected=177.582016
# Time_value=360, Predicted=356.889503, Expected=174.664902
# Time_value=361, Predicted=353.690310, Expected=174.935165
# Time_value=362, Predicted=349.236234, Expected=173.751526
# Time_value=363, Predicted=349.214503, Expected=173.602417
# Time_value=364, Predicted=347.442644, Expected=175.652802
# Time_value=365, Predicted=347.064894, Expected=177.358337
# Time_value=366, Predicted=349.971683, Expected=180.871948
# Time_value=367, Predicted=352.612993, Expected=179.585800
# Time_value=368, Predicted=357.725104, Expected=181.673492
# Time_value=369, Predicted=356.395785, Expected=183.071457
# Time_value=370, Predicted=359.211823, Expected=182.819824
# Time_value=371, Predicted=361.326145, Expected=184.916794
# Time_value=372, Predicted=361.192440, Expected=184.637222
# Time_value=373, Predicted=364.007877, Expected=185.820847
# Time_value=374, Predicted=363.873067, Expected=187.945801
# Time_value=375, Predicted=365.457361, Expected=188.048309
# Time_value=376, Predicted=368.345652, Expected=187.395935
# Time_value=377, Predicted=368.727560, Expected=188.579544
# Time_value=378, Predicted=367.968044, Expected=189.334457
# Time_value=379, Predicted=369.446116, Expected=189.511566
# Time_value=380, Predicted=370.516991, Expected=190.108017
# Time_value=381, Predicted=370.844434, Expected=190.294418
# Time_value=382, Predicted=371.644053, Expected=190.089401
# Time_value=383, Predicted=371.951643, Expected=190.303741
# Time_value=384, Predicted=371.733703, Expected=190.350342
# Time_value=385, Predicted=371.996455, Expected=190.471466
# Time_value=386, Predicted=372.075506, Expected=191.571243
# Time_value=387, Predicted=372.237835, Expected=191.263687
# Time_value=388, Predicted=373.624969, Expected=191.599182
# Time_value=389, Predicted=373.350439, Expected=192.624405
# Time_value=390, Predicted=373.768582, Expected=193.164948
# Time_value=391, Predicted=375.069879, Expected=193.025162
# Time_value=392, Predicted=375.837134, Expected=193.519119
# Time_value=393, Predicted=375.744406, Expected=193.109039
# Time_value=394, Predicted=376.360820, Expected=191.766983
# Time_value=395, Predicted=375.909801, Expected=193.006500
# Time_value=396, Predicted=374.236591, Expected=193.752121
# Time_value=397, Predicted=375.636278, Expected=193.537750
# Time_value=398, Predicted=376.624947, Expected=193.854630
# Time_value=399, Predicted=376.448426, Expected=192.559174
# Time_value=400, Predicted=376.840841, Expected=192.428711
# Time_value=401, Predicted=375.288916, Expected=189.343750
# Time_value=402, Predicted=375.021352, Expected=190.303741
# Time_value=403, Predicted=371.135585, Expected=187.228165
# Time_value=404, Predicted=372.034449, Expected=185.942001
# Time_value=405, Predicted=368.136180, Expected=184.450836
# Time_value=406, Predicted=366.156698, Expected=188.066925
# Time_value=407, Predicted=363.984743, Expected=192.717575
# Time_value=408, Predicted=368.469288, Expected=193.537506
# Time_value=409, Predicted=374.618374, Expected=194.427811
# Time_value=410, Predicted=376.126777, Expected=194.690201
# Time_value=411, Predicted=377.423403, Expected=194.708939
# Time_value=412, Predicted=377.889595, Expected=195.336807
# Time_value=413, Predicted=377.984205, Expected=195.599213
# Time_value=414, Predicted=378.768672, Expected=194.549622
# Time_value=415, Predicted=379.148797, Expected=192.619110
# Time_value=416, Predicted=377.928366, Expected=192.516037
# Time_value=417, Predicted=375.501807, Expected=189.039246
# Time_value=418, Predicted=375.181908, Expected=187.258698
# Time_value=419, Predicted=370.780639, Expected=189.592163
# Time_value=420, Predicted=368.148778, Expected=192.956482
# Time_value=421, Predicted=370.845559, Expected=191.410187
# Time_value=422, Predicted=375.184302, Expected=189.910797
# Time_value=423, Predicted=373.614219, Expected=189.376617
# Time_value=424, Predicted=371.692221, Expected=188.233292
# Time_value=425, Predicted=370.870094, Expected=186.508987
# Time_value=426, Predicted=369.325668, Expected=188.954910
# Time_value=427, Predicted=366.966308, Expected=189.357895
# Time_value=428, Predicted=369.890875, Expected=190.313797
# Time_value=429, Predicted=370.586076, Expected=193.143921
# Time_value=430, Predicted=371.872247, Expected=192.084946
# Time_value=431, Predicted=375.500217, Expected=192.534760
# Time_value=432, Predicted=374.488596, Expected=189.995132
# Time_value=433, Predicted=375.030583, Expected=187.558563
# Time_value=434, Predicted=371.919266, Expected=189.292297
# Time_value=435, Predicted=368.598711, Expected=186.911926
# Time_value=436, Predicted=370.506482, Expected=189.226685
# Time_value=437, Predicted=367.550973, Expected=191.963135
# Time_value=438, Predicted=370.289412, Expected=191.232147
# Time_value=439, Predicted=373.890437, Expected=193.162628
# Time_value=440, Predicted=373.278320, Expected=192.628494
# Time_value=441, Predicted=375.678114, Expected=191.766342
# Time_value=442, Predicted=375.209370, Expected=193.809280
# Time_value=443, Predicted=374.151063, Expected=193.921722
# Time_value=444, Predicted=376.588586, Expected=195.786682
# Time_value=445, Predicted=376.890300, Expected=196.592560
# Time_value=446, Predicted=379.197437, Expected=196.901855
# Time_value=447, Predicted=380.337889, Expected=196.920593
# Time_value=448, Predicted=380.825029, Expected=196.779999
# Time_value=449, Predicted=380.912411, Expected=197.960800
# Time_value=450, Predicted=380.770543, Expected=197.932663
# Time_value=451, Predicted=382.164764, Expected=198.494949
# Time_value=452, Predicted=382.226986, Expected=198.326263
# Time_value=453, Predicted=382.913450, Expected=198.091995
# Time_value=454, Predicted=382.770439, Expected=197.417282
# Time_value=455, Predicted=382.500250, Expected=198.663651
# Time_value=456, Predicted=381.691150, Expected=197.848312
# Time_value=457, Predicted=383.098128, Expected=197.014297
# Time_value=458, Predicted=382.222404, Expected=197.229858
# Time_value=459, Predicted=381.197173, Expected=194.455902
# Time_value=460, Predicted=381.374761, Expected=195.261841
# Time_value=461, Predicted=378.054950, Expected=192.094345
# Time_value=462, Predicted=378.786628, Expected=191.644501
# Time_value=463, Predicted=374.933094, Expected=194.081070
# Time_value=464, Predicted=374.084734, Expected=192.890869
# Time_value=465, Predicted=376.949922, Expected=195.468018
# Time_value=466, Predicted=375.672515, Expected=194.887009
# Time_value=467, Predicted=378.740534, Expected=197.229858
# Time_value=468, Predicted=378.249618, Expected=196.330200
# Time_value=469, Predicted=381.059390, Expected=198.062973
# Time_value=470, Predicted=380.191267, Expected=197.677048
# Time_value=471, Predicted=382.228922, Expected=196.566269
# Time_value=472, Predicted=381.914816, Expected=193.685822
# Time_value=473, Predicted=380.612605, Expected=193.224609
# Time_value=474, Predicted=377.069599, Expected=193.667007
# Time_value=475, Predicted=376.233960, Expected=196.029694
# Time_value=476, Predicted=376.651857, Expected=194.316483
# Time_value=477, Predicted=379.501965, Expected=193.629333
# Time_value=478, Predicted=377.636720, Expected=194.325928
# Time_value=479, Predicted=376.710590, Expected=195.634369
# Time_value=480, Predicted=377.474706, Expected=195.116638
# Time_value=481, Predicted=379.088295, Expected=195.775543
# Time_value=482, Predicted=378.585669, Expected=196.641571
# Time_value=483, Predicted=379.367693, Expected=197.714645
# Time_value=484, Predicted=380.457063, Expected=196.820435
# Time_value=485, Predicted=381.815470, Expected=197.196976
# Time_value=486, Predicted=380.871494, Expected=198.081802
# Time_value=487, Predicted=381.281717, Expected=198.025299
# Time_value=488, Predicted=382.348528, Expected=195.747330
# Time_value=489, Predicted=382.359028, Expected=197.535858
# Time_value=490, Predicted=379.679691, Expected=197.300522
# Time_value=491, Predicted=381.626099, Expected=198.270065
# Time_value=492, Predicted=381.442444, Expected=198.768921
# Time_value=493, Predicted=382.588962, Expected=199.230209
# Time_value=494, Predicted=383.252509, Expected=198.401840
# Time_value=495, Predicted=383.852864, Expected=199.032516
# Time_value=496, Predicted=382.942027, Expected=198.213577
# Time_value=497, Predicted=383.634190, Expected=196.227402
# Time_value=498, Predicted=382.714128, Expected=198.354767
# Time_value=499, Predicted=380.315224, Expected=198.919571
# Time_value=500, Predicted=382.653490, Expected=196.641571
# Time_value=501, Predicted=383.430490, Expected=195.832031
# Time_value=502, Predicted=380.824202, Expected=196.613327
# Time_value=503, Predicted=379.702084, Expected=199.201950
# Time_value=504, Predicted=380.521223, Expected=198.251236
# Time_value=505, Predicted=383.596849, Expected=197.658157
# Time_value=506, Predicted=382.691812, Expected=197.695862
# Time_value=507, Predicted=381.983246, Expected=199.757355
# Time_value=508, Predicted=381.982719, Expected=199.973846
# Time_value=509, Predicted=384.383178, Expected=200.595108
# Time_value=510, Predicted=384.787083, Expected=200.529221
# Time_value=511, Predicted=385.566132, Expected=200.388046
# Time_value=512, Predicted=385.558305, Expected=200.971649
# Time_value=513, Predicted=385.414106, Expected=200.491592
# Time_value=514, Predicted=386.083403, Expected=198.335938
# Time_value=515, Predicted=385.574085, Expected=200.218582
# Time_value=516, Predicted=383.051594, Expected=199.992661
# Time_value=517, Predicted=385.071973, Expected=198.750137
# Time_value=518, Predicted=384.901002, Expected=199.154892
# Time_value=519, Predicted=383.464166, Expected=198.957230
# Time_value=520, Predicted=383.845370, Expected=199.484360
# Time_value=521, Predicted=383.618872, Expected=197.799393
# Time_value=522, Predicted=384.215856, Expected=197.460526
# Time_value=523, Predicted=382.282247, Expected=196.189728
# Time_value=524, Predicted=381.761985, Expected=196.217987
# Time_value=525, Predicted=380.193095, Expected=198.580704
# Time_value=526, Predicted=380.100301, Expected=199.230209
# Time_value=527, Predicted=382.855357, Expected=197.611115
# Time_value=528, Predicted=383.785818, Expected=196.829865
# Time_value=529, Predicted=381.988958, Expected=197.912338
# Time_value=530, Predicted=380.973040, Expected=198.232391
# Time_value=531, Predicted=382.163923, Expected=200.228012
# Time_value=532, Predicted=382.598577, Expected=199.405136
# Time_value=533, Predicted=384.962986, Expected=200.426712
# Time_value=534, Predicted=384.172157, Expected=200.578049
# Time_value=535, Predicted=385.344039, Expected=199.121353
# Time_value=536, Predicted=385.595066, Expected=198.478134
# Time_value=537, Predicted=383.944562, Expected=198.544373
# Time_value=538, Predicted=383.098593, Expected=194.354034
# Time_value=539, Predicted=383.098837, Expected=194.751297
# Time_value=540, Predicted=378.102264, Expected=196.340424
# Time_value=541, Predicted=378.220271, Expected=196.103958
# Time_value=542, Predicted=380.054094, Expected=195.489105
# Time_value=543, Predicted=379.874501, Expected=196.756622
# Time_value=544, Predicted=379.145248, Expected=193.464890
# Time_value=545, Predicted=380.610101, Expected=193.720261
# Time_value=546, Predicted=376.743785, Expected=196.255280
# Time_value=547, Predicted=376.794923, Expected=198.411926
# Time_value=548, Predicted=379.802315, Expected=199.319992
# Time_value=549, Predicted=382.548701, Expected=199.234879
# Time_value=550, Predicted=383.833697, Expected=200.786163
# Time_value=551, Predicted=383.873662, Expected=200.975311
# Time_value=552, Predicted=385.710747, Expected=201.117203
# Time_value=553, Predicted=386.059057, Expected=200.303741
# Time_value=554, Predicted=386.277614, Expected=199.859146
# Time_value=555, Predicted=385.374102, Expected=198.771362
# Time_value=556, Predicted=384.814035, Expected=196.690399
# Time_value=557, Predicted=383.504932, Expected=195.555313
# Time_value=558, Predicted=380.960624, Expected=197.986298
# Time_value=559, Predicted=379.409656, Expected=199.367294
# Time_value=560, Predicted=382.138524, Expected=199.414612
# Time_value=561, Predicted=383.898380, Expected=199.064621
# Time_value=562, Predicted=384.095939, Expected=198.383545
# Time_value=563, Predicted=383.737531, Expected=197.995758
# Time_value=564, Predicted=382.934409, Expected=198.733566
# Time_value=565, Predicted=382.426743, Expected=197.078217
# Time_value=566, Predicted=383.245147, Expected=196.671463
# Time_value=567, Predicted=381.342193, Expected=199.234879
# Time_value=568, Predicted=380.739824, Expected=197.371429
# Time_value=569, Predicted=383.687507, Expected=197.617401
# Time_value=570, Predicted=381.680217, Expected=197.409302
# Time_value=571, Predicted=381.874998, Expected=198.033569
# Time_value=572, Predicted=381.625089, Expected=199.168686
# Time_value=573, Predicted=382.340471, Expected=198.572723
# Time_value=574, Predicted=383.711774, Expected=197.012024
# Time_value=575, Predicted=383.115567, Expected=192.973007
# Time_value=576, Predicted=381.265229, Expected=186.938187
# Time_value=577, Predicted=376.284806, Expected=179.295303
# Time_value=578, Predicted=368.329548, Expected=177.100784
# Time_value=579, Predicted=357.440891, Expected=184.147751
# Time_value=580, Predicted=353.314140, Expected=188.385376
# Time_value=581, Predicted=362.421425, Expected=188.461060
# Time_value=582, Predicted=368.556809, Expected=186.853043
# Time_value=583, Predicted=369.202944, Expected=181.395203
# Time_value=584, Predicted=367.289988, Expected=184.838287
# Time_value=585, Predicted=359.956572, Expected=185.065247
# Time_value=586, Predicted=363.945354, Expected=182.170807
# Time_value=587, Predicted=364.465941, Expected=186.777374
# Time_value=588, Predicted=360.677543, Expected=184.223450
# Time_value=589, Predicted=366.477427, Expected=185.254501
# Time_value=590, Predicted=363.544484, Expected=186.096329
# Time_value=591, Predicted=364.732811, Expected=185.377411
# Time_value=592, Predicted=365.908845, Expected=187.713821
# Time_value=593, Predicted=365.072079, Expected=189.312363
# Time_value=594, Predicted=368.058009, Expected=188.896210
# Time_value=595, Predicted=370.325958, Expected=185.752213
# Time_value=596, Predicted=370.012116, Expected=186.779144
# Time_value=597, Predicted=365.985839, Expected=184.364029
# Time_value=598, Predicted=367.010322, Expected=184.078796
# Time_value=599, Predicted=363.882111, Expected=183.441742
# Time_value=600, Predicted=363.251749, Expected=183.384674
# Time_value=601, Predicted=362.312147, Expected=178.668610
# Time_value=602, Predicted=362.138987, Expected=178.830276
# Time_value=603, Predicted=355.686904, Expected=182.167618
# Time_value=604, Predicted=355.371142, Expected=182.681091
# Time_value=605, Predicted=359.840170, Expected=185.409927
# Time_value=606, Predicted=360.861224, Expected=188.709274
# Time_value=607, Predicted=364.611082, Expected=188.062714
# Time_value=608, Predicted=369.199426, Expected=189.603043
# Time_value=609, Predicted=368.782969, Expected=191.314560
# Time_value=610, Predicted=370.790617, Expected=191.428635
# Time_value=611, Predicted=373.111219, Expected=191.609299
# Time_value=612, Predicted=373.463915, Expected=190.401749
# Time_value=613, Predicted=373.761246, Expected=189.488953
# Time_value=614, Predicted=372.299258, Expected=192.398483
# Time_value=615, Predicted=371.052155, Expected=193.273224
# Time_value=616, Predicted=374.572707, Expected=193.368301
# Time_value=617, Predicted=375.887285, Expected=193.121078
# Time_value=618, Predicted=376.145188, Expected=191.923050
# Time_value=619, Predicted=375.896122, Expected=195.117828
# Time_value=620, Predicted=374.419845, Expected=197.314209
# Time_value=621, Predicted=378.213953, Expected=196.810303
# Time_value=622, Predicted=381.088928, Expected=196.410934
# Time_value=623, Predicted=380.739943, Expected=198.664368
# Time_value=624, Predicted=380.302896, Expected=198.616837
# Time_value=625, Predicted=382.949483, Expected=197.704025
# Time_value=626, Predicted=383.070193, Expected=200.043076
# Time_value=627, Predicted=382.048618, Expected=200.623032
# Time_value=628, Predicted=384.728694, Expected=200.033569
# Time_value=629, Predicted=385.562405, Expected=199.814880
# Time_value=630, Predicted=384.973518, Expected=199.710281
# Time_value=631, Predicted=384.709858, Expected=197.846664
# Time_value=632, Predicted=384.572672, Expected=198.303055
# Time_value=633, Predicted=382.386772, Expected=197.523392
# Time_value=634, Predicted=382.774000, Expected=194.766006
# Time_value=635, Predicted=381.848711, Expected=192.579117
# Time_value=636, Predicted=378.495545, Expected=195.507660
# Time_value=637, Predicted=375.582168, Expected=195.365005
# Time_value=638, Predicted=378.865755, Expected=198.464706
# Time_value=639, Predicted=378.864189, Expected=198.293549
# Time_value=640, Predicted=382.573278, Expected=199.016159
# Time_value=641, Predicted=382.630287, Expected=198.787979
# Time_value=642, Predicted=383.538958, Expected=199.054230
# Time_value=643, Predicted=383.353769, Expected=199.025696
# Time_value=644, Predicted=383.674156, Expected=199.253891
# Time_value=645, Predicted=383.667258, Expected=198.426666
# Time_value=646, Predicted=383.939826, Expected=200.318787
# Time_value=647, Predicted=382.995307, Expected=198.274551
# Time_value=648, Predicted=385.138727, Expected=195.498108
# Time_value=649, Predicted=382.888091, Expected=199.310913
# Time_value=650, Predicted=379.482798, Expected=198.103409
# Time_value=651, Predicted=383.726102, Expected=196.772217
# Time_value=652, Predicted=382.536821, Expected=195.241425
# Time_value=653, Predicted=380.932773, Expected=195.745361
# Time_value=654, Predicted=378.993709, Expected=191.951584
# Time_value=655, Predicted=379.434969, Expected=192.921417
# Time_value=656, Predicted=374.820400, Expected=194.946655
# Time_value=657, Predicted=375.664896, Expected=197.799103
# Time_value=658, Predicted=378.117508, Expected=194.785019
# Time_value=659, Predicted=381.684564, Expected=191.314514
# Time_value=660, Predicted=378.368810, Expected=192.892685
# Time_value=661, Predicted=373.958678, Expected=194.643021
# Time_value=662, Predicted=375.547202, Expected=197.053360
# Time_value=663, Predicted=377.721283, Expected=196.728149
# Time_value=664, Predicted=380.764698, Expected=196.278610
# Time_value=665, Predicted=380.620565, Expected=198.373276
# Time_value=666, Predicted=380.132996, Expected=196.967285
# Time_value=667, Predicted=382.593995, Expected=194.996918
# Time_value=668, Predicted=381.101698, Expected=192.270966
# Time_value=669, Predicted=378.687232, Expected=192.596176
# Time_value=670, Predicted=375.191276, Expected=190.166733
# Time_value=671, Predicted=375.291617, Expected=185.604340
# Time_value=672, Predicted=372.217111, Expected=183.567032
# Time_value=673, Predicted=366.129153, Expected=183.748795
# Time_value=674, Predicted=362.902725, Expected=185.231293
# Time_value=675, Predicted=362.777382, Expected=180.611511
# Time_value=676, Predicted=364.649058, Expected=183.576599
# Time_value=677, Predicted=358.587684, Expected=179.635910
# Time_value=678, Predicted=362.108377, Expected=179.875031
# Time_value=679, Predicted=356.979087, Expected=177.569931
# Time_value=680, Predicted=356.909424, Expected=178.564651
# Time_value=681, Predicted=353.643277, Expected=182.227982
# Time_value=682, Predicted=354.750179, Expected=179.473343
# Time_value=683, Predicted=359.823639, Expected=181.921890
# Time_value=684, Predicted=356.464320, Expected=179.941986
# Time_value=685, Predicted=359.598942, Expected=180.879349
# Time_value=686, Predicted=357.126051, Expected=185.288696
# Time_value=687, Predicted=358.240446, Expected=185.221741
# Time_value=688, Predicted=364.219847, Expected=181.883652
# Time_value=689, Predicted=364.611448, Expected=182.974014
# Time_value=690, Predicted=360.273605, Expected=183.260971
# Time_value=691, Predicted=361.417276, Expected=179.769806
# Time_value=692, Predicted=361.848807, Expected=177.349930
# Time_value=693, Predicted=357.150645, Expected=177.359482
# Time_value=694, Predicted=353.403951, Expected=177.206451
# Time_value=695, Predicted=353.057647, Expected=174.901367
# Time_value=696, Predicted=352.757737, Expected=178.507278
# Time_value=697, Predicted=349.429420, Expected=181.520187
# Time_value=698, Predicted=354.260990, Expected=184.485275
# Time_value=699, Predicted=358.758612, Expected=183.729630
# Time_value=700, Predicted=363.132568, Expected=183.643555
# Time_value=701, Predicted=362.537179, Expected=186.302567
# Time_value=702, Predicted=362.446295, Expected=183.949631
# Time_value=703, Predicted=365.955273, Expected=184.791321
# Time_value=704, Predicted=363.144839, Expected=187.029465
# Time_value=705, Predicted=364.081712, Expected=186.599075
# Time_value=706, Predicted=367.058447, Expected=185.135651
# Time_value=707, Predicted=366.741924, Expected=189.487625
# Time_value=708, Predicted=364.850334, Expected=190.338898
# Time_value=709, Predicted=370.323547, Expected=191.084915
# Time_value=710, Predicted=371.796527, Expected=191.706650
# Time_value=711, Predicted=372.912966, Expected=191.859695
# Time_value=712, Predicted=373.813943, Expected=189.764999
# Time_value=713, Predicted=374.101829, Expected=190.702347
# Time_value=714, Predicted=371.532758, Expected=190.855408
# Time_value=715, Predicted=372.525905, Expected=193.935242
# Time_value=716, Predicted=372.760045, Expected=193.686539
# Time_value=717, Predicted=376.582127, Expected=193.370911
# Time_value=718, Predicted=376.563073, Expected=194.489990
# Time_value=719, Predicted=376.235983, Expected=195.723862
# Time_value=720, Predicted=377.592760, Expected=196.492615
# Time_value=721, Predicted=379.178853, Expected=196.771393
# Time_value=722, Predicted=380.230880, Expected=196.665649
# Time_value=723, Predicted=380.667265, Expected=195.367767
# Time_value=724, Predicted=380.599090, Expected=195.281235
# Time_value=725, Predicted=379.061594, Expected=195.396591
# Time_value=726, Predicted=378.854852, Expected=197.204041
# Time_value=727, Predicted=378.957248, Expected=198.069305
# Time_value=728, Predicted=381.109834, Expected=197.588623
# Time_value=729, Predicted=382.276516, Expected=198.934570
# Time_value=730, Predicted=381.821452, Expected=198.290451
# Time_value=731, Predicted=383.399316, Expected=196.309921
# Time_value=732, Predicted=382.753584, Expected=198.453857
# Time_value=733, Predicted=380.398557, Expected=196.079178
# Time_value=734, Predicted=382.769053, Expected=196.607986
# Time_value=735, Predicted=380.087081, Expected=196.146515
# Time_value=736, Predicted=380.556713, Expected=197.973175
# Time_value=737, Predicted=380.006661, Expected=199.972916
# Time_value=738, Predicted=382.128821, Expected=199.982513
# Time_value=739, Predicted=384.596881, Expected=199.761368
# Time_value=740, Predicted=384.796549, Expected=201.165054
# Time_value=741, Predicted=384.601122, Expected=201.799576
# Time_value=742, Predicted=386.227128, Expected=201.991867
# Time_value=743, Predicted=387.059303, Expected=200.905472
# Time_value=744, Predicted=387.356367, Expected=200.905472
# Time_value=745, Predicted=386.155399, Expected=200.559357
# Time_value=746, Predicted=386.094236, Expected=200.857407
# Time_value=747, Predicted=385.679477, Expected=201.270798
# Time_value=748, Predicted=385.990688, Expected=199.444107
# Time_value=749, Predicted=386.476079, Expected=198.367355
# Time_value=750, Predicted=384.403424, Expected=199.944061
# Time_value=751, Predicted=383.024368, Expected=198.203903
# Time_value=752, Predicted=384.739593, Expected=197.098251
# Time_value=753, Predicted=382.793215, Expected=197.059830
# Time_value=754, Predicted=381.378527, Expected=197.780884
# Time_value=755, Predicted=381.211595, Expected=197.944336
# Time_value=756, Predicted=382.020330, Expected=200.405518
# Time_value=757, Predicted=382.253614, Expected=198.530792
# Time_value=758, Predicted=385.144963, Expected=198.588470
# Time_value=759, Predicted=383.159617, Expected=196.857925
# Time_value=760, Predicted=383.144158, Expected=198.800003
# Time_value=761, Predicted=381.093022, Expected=196.944458
# Time_value=762, Predicted=383.234408, Expected=197.002151
# Time_value=763, Predicted=381.162383, Expected=196.319550
# Time_value=764, Predicted=381.112019, Expected=197.559738
# Time_value=765, Predicted=380.273230, Expected=197.290573
# Time_value=766, Predicted=381.676115, Expected=199.847931
# Time_value=767, Predicted=381.437348, Expected=201.203522
# Time_value=768, Predicted=384.432016, Expected=201.261169
# Time_value=769, Predicted=386.191739, Expected=202.126450
# Time_value=770, Predicted=386.414077, Expected=201.741898
# Time_value=771, Predicted=387.459256, Expected=202.155289
# Time_value=772, Predicted=387.103835, Expected=202.770615
# Time_value=773, Predicted=387.576546, Expected=202.164902
# Time_value=774, Predicted=388.307121, Expected=203.193619
# Time_value=775, Predicted=387.672508, Expected=203.510864
# Time_value=776, Predicted=388.814602, Expected=204.174240
# Time_value=777, Predicted=389.235721, Expected=203.895462
# Time_value=778, Predicted=390.021308, Expected=201.963013
# Time_value=779, Predicted=389.765844, Expected=200.405518
# Time_value=780, Predicted=387.585227, Expected=200.011337
# Time_value=781, Predicted=385.676059, Expected=199.732559
# Time_value=782, Predicted=385.069890, Expected=200.328613
# Time_value=783, Predicted=384.667540, Expected=199.582993
# Time_value=784, Predicted=385.306117, Expected=200.868301
# Time_value=785, Predicted=384.469115, Expected=201.438477
# Time_value=786, Predicted=385.903274, Expected=201.109924
# Time_value=787, Predicted=386.635478, Expected=203.728851
# Time_value=788, Predicted=386.322037, Expected=196.413162
# Time_value=789, Predicted=389.295914, Expected=192.895432
# Time_value=790, Predicted=381.039914, Expected=196.374496
# Time_value=791, Predicted=376.303638, Expected=199.718262
# Time_value=792, Predicted=380.045291, Expected=202.443527
# Time_value=793, Predicted=384.132443, Expected=202.868774
# Time_value=794, Predicted=387.552559, Expected=201.409500
# Time_value=795, Predicted=388.310904, Expected=202.617508
# Time_value=796, Predicted=386.770587, Expected=202.491867
# Time_value=797, Predicted=388.091433, Expected=205.507065
# Time_value=798, Predicted=388.019993, Expected=206.231857
# Time_value=799, Predicted=391.420329, Expected=207.729797
# Time_value=800, Predicted=392.419864, Expected=207.700821
# Time_value=801, Predicted=394.172185, Expected=208.860504
# Time_value=802, Predicted=394.264002, Expected=208.580246
# Time_value=803, Predicted=395.569289, Expected=209.140762
# Time_value=804, Predicted=395.345205, Expected=208.928162
# Time_value=805, Predicted=395.966589, Expected=209.797943
# Time_value=806, Predicted=395.773227, Expected=209.005463
# Time_value=807, Predicted=396.715425, Expected=209.942902
# Time_value=808, Predicted=395.906026, Expected=209.372681
# Time_value=809, Predicted=396.893461, Expected=209.469345
# Time_value=810, Predicted=396.319647, Expected=209.247086
# Time_value=811, Predicted=396.408139, Expected=209.488663
# Time_value=812, Predicted=396.169155, Expected=209.826920
# Time_value=813, Predicted=396.418788, Expected=209.652954
# Time_value=814, Predicted=396.792224, Expected=208.309662
# Time_value=815, Predicted=396.624177, Expected=208.918472
# Time_value=816, Predicted=395.168163, Expected=209.140762
# Time_value=817, Predicted=395.758634, Expected=210.851318
# Time_value=818, Predicted=396.008486, Expected=210.725677
# Time_value=819, Predicted=397.862702, Expected=210.851318
# Time_value=820, Predicted=397.816015, Expected=210.329453
# Time_value=821, Predicted=397.973567, Expected=211.305527
# Time_value=822, Predicted=397.430822, Expected=211.121902
# Time_value=823, Predicted=398.457353, Expected=211.730728
# Time_value=824, Predicted=398.302355, Expected=210.638733
# Time_value=825, Predicted=398.956231, Expected=211.034927
# Time_value=826, Predicted=397.821432, Expected=211.508484
# Time_value=827, Predicted=398.204594, Expected=211.199203
# Time_value=828, Predicted=398.716750, Expected=211.189575
# Time_value=829, Predicted=398.409780, Expected=211.614777
# ...
# Time_value=1014, Predicted=423.811839, Expected=232.334564
# Time_value=1015, Predicted=419.781572, Expected=233.845703
# Time_value=1016, Predicted=420.659950, Expected=235.033051
# Time_value=1017, Predicted=422.126608, Expected=235.553131
# Time_value=1018, Predicted=423.277301, Expected=236.102631
# Time_value=1019, Predicted=423.781620, Expected=237.231094
# Time_value=1020, Predicted=424.309081, Expected=237.182053
# Time_value=1021, Predicted=425.387339, Expected=236.975983
# Time_value=1022, Predicted=425.340430, Expected=236.917084
# Time_value=1023, Predicted=425.140731, Expected=238.801132
# Time_value=1024, Predicted=425.082689, Expected=239.595947
# Time_value=1025, Predicted=426.875341, Expected=239.419327
# Time_value=1026, Predicted=427.628411, Expected=238.653946
# Time_value=1027, Predicted=427.454448, Expected=239.095520
# Time_value=1028, Predicted=426.723418, Expected=239.213242
# Time_value=1029, Predicted=427.141196, Expected=238.850204
# Time_value=1030, Predicted=427.252690, Expected=238.801132
# Time_value=1031, Predicted=426.906385, Expected=239.968826
# Time_value=1032, Predicted=426.858983, Expected=239.664642
# Time_value=1033, Predicted=427.966572, Expected=239.203430
# Time_value=1034, Predicted=427.676428, Expected=239.255707
# Time_value=1035, Predicted=427.236211, Expected=241.247528
# Time_value=1036, Predicted=427.285867, Expected=239.620544
# Time_value=1037, Predicted=429.171835, Expected=239.561371
# Time_value=1038, Predicted=427.627794, Expected=239.452911
# Time_value=1039, Predicted=427.569154, Expected=239.738861
# Time_value=1040, Predicted=427.468858, Expected=239.896622
# Time_value=1041, Predicted=427.740718, Expected=237.963989
# Time_value=1042, Predicted=427.890228, Expected=240.093857
# Time_value=1043, Predicted=426.055507, Expected=237.983704
# Time_value=1044, Predicted=428.078384, Expected=238.427414
# Time_value=1045, Predicted=426.078448, Expected=238.831711
# Time_value=1046, Predicted=426.498952, Expected=239.383896
# Time_value=1047, Predicted=426.887337, Expected=237.194855
# Time_value=1048, Predicted=427.411666, Expected=238.733093
# Time_value=1049, Predicted=425.330120, Expected=238.989456
# Time_value=1050, Predicted=426.793147, Expected=238.811981
# Time_value=1051, Predicted=427.040842, Expected=240.606583
# Time_value=1052, Predicted=426.870336, Expected=241.010880
# Time_value=1053, Predicted=428.570281, Expected=242.134964
# Time_value=1054, Predicted=428.948809, Expected=242.105377
# Time_value=1055, Predicted=430.002665, Expected=242.233566
# Time_value=1056, Predicted=429.966339, Expected=243.545029
# Time_value=1057, Predicted=430.080373, Expected=243.653503
# Time_value=1058, Predicted=431.310390, Expected=243.436569
# Time_value=1059, Predicted=431.402895, Expected=243.377411
# Time_value=1060, Predicted=431.190698, Expected=243.969025
# Time_value=1061, Predicted=431.131626, Expected=243.978897
# Time_value=1062, Predicted=431.685758, Expected=243.752106
# Time_value=1063, Predicted=431.690431, Expected=243.466156
# Time_value=1064, Predicted=431.473634, Expected=243.328110
# Time_value=1065, Predicted=431.204172, Expected=243.870422
# Time_value=1066, Predicted=431.075673, Expected=243.988739
# Time_value=1067, Predicted=431.586723, Expected=243.515457
# Time_value=1068, Predicted=431.695665, Expected=243.959167
# Time_value=1069, Predicted=431.248382, Expected=244.412735
# Time_value=1070, Predicted=431.666245, Expected=243.811264
# Time_value=1071, Predicted=432.090746, Expected=243.801407
# Time_value=1072, Predicted=431.521985, Expected=240.360077
# Time_value=1073, Predicted=431.513359, Expected=240.715057
# Time_value=1074, Predicted=428.273368, Expected=243.101303
# Time_value=1075, Predicted=428.623394, Expected=243.071716
# Time_value=1076, Predicted=430.886025, Expected=243.495728
# Time_value=1077, Predicted=430.853486, Expected=239.699417
# Time_value=1078, Predicted=431.246048, Expected=239.324738
# Time_value=1079, Predicted=427.661984, Expected=239.512070
# Time_value=1080, Predicted=427.317854, Expected=242.016663
# Time_value=1081, Predicted=427.508808, Expected=241.148911
# Time_value=1082, Predicted=429.882751, Expected=240.586884
# Time_value=1083, Predicted=429.059595, Expected=241.148911
# Time_value=1084, Predicted=428.525115, Expected=241.158783
# Time_value=1085, Predicted=429.058803, Expected=241.434891
# Time_value=1086, Predicted=429.068546, Expected=242.578690
# Time_value=1087, Predicted=429.328123, Expected=244.038055
# Time_value=1088, Predicted=430.405135, Expected=244.383163
# Time_value=1089, Predicted=431.771527, Expected=242.627991
# Time_value=1090, Predicted=432.082551, Expected=243.456284
# Time_value=1091, Predicted=430.422101, Expected=243.426712
# Time_value=1092, Predicted=431.204063, Expected=243.140762
# Time_value=1093, Predicted=431.176219, Expected=245.734070
# Time_value=1094, Predicted=430.905072, Expected=246.562347
# Time_value=1095, Predicted=433.338570, Expected=246.680679
# Time_value=1096, Predicted=434.097692, Expected=246.601791
# Time_value=1097, Predicted=434.189362, Expected=246.933762
# Time_value=1098, Predicted=434.104088, Expected=247.458969
# Time_value=1099, Predicted=434.408130, Expected=247.706696
# Time_value=1100, Predicted=434.891909, Expected=247.795883
# Time_value=1101, Predicted=435.114076, Expected=247.131958
# Time_value=1102, Predicted=435.189281, Expected=247.181503
# Time_value=1103, Predicted=434.564466, Expected=246.676102
# Time_value=1104, Predicted=434.612845, Expected=246.824753
# Time_value=1105, Predicted=434.142327, Expected=247.785980
# Time_value=1106, Predicted=434.285247, Expected=248.083267
# Time_value=1107, Predicted=435.183662, Expected=248.955292
# Time_value=1108, Predicted=435.453092, Expected=250.035431
# Time_value=1109, Predicted=436.257179, Expected=250.570541
# Time_value=1110, Predicted=437.249147, Expected=250.867813
# Time_value=1111, Predicted=437.727608, Expected=252.354233
# Time_value=1112, Predicted=437.986757, Expected=252.066849
# Time_value=1113, Predicted=439.351462, Expected=251.650665
# Time_value=1114, Predicted=439.061111, Expected=252.314590
# Time_value=1115, Predicted=438.663763, Expected=252.710983
# Time_value=1116, Predicted=439.277072, Expected=252.334427
# Time_value=1117, Predicted=439.634960, Expected=252.641617
# Time_value=1118, Predicted=439.275612, Expected=252.978531
# Time_value=1119, Predicted=439.557818, Expected=253.156906
# Time_value=1120, Predicted=439.864809, Expected=253.404633
# Time_value=1121, Predicted=440.022333, Expected=253.473999
# Time_value=1122, Predicted=440.244644, Expected=254.782043
# Time_value=1123, Predicted=440.301828, Expected=253.791092
# Time_value=1124, Predicted=441.504429, Expected=254.237030
# Time_value=1125, Predicted=440.570220, Expected=252.978531
# Time_value=1126, Predicted=440.982571, Expected=253.305527
# Time_value=1127, Predicted=439.815921, Expected=255.376602
# Time_value=1128, Predicted=440.130274, Expected=254.425308
# Time_value=1129, Predicted=442.045377, Expected=254.821701
# Time_value=1130, Predicted=441.142409, Expected=255.158600
# Time_value=1131, Predicted=441.505070, Expected=255.257706
# Time_value=1132, Predicted=441.810578, Expected=256.109955
# Time_value=1133, Predicted=441.893599, Expected=256.506287
# Time_value=1134, Predicted=442.672531, Expected=256.327942
# Time_value=1135, Predicted=443.022222, Expected=256.763916
# Time_value=1136, Predicted=442.843402, Expected=255.832458
# Time_value=1137, Predicted=443.238862, Expected=255.753189
# Time_value=1138, Predicted=442.372131, Expected=255.990982
# Time_value=1139, Predicted=442.306096, Expected=255.396454
# Time_value=1140, Predicted=442.530454, Expected=254.118118
# Time_value=1141, Predicted=441.981832, Expected=256.278381
# Time_value=1142, Predicted=440.810322, Expected=255.525253
# Time_value=1143, Predicted=442.822885, Expected=255.961258
# Time_value=1144, Predicted=442.112755, Expected=257.635956
# Time_value=1145, Predicted=442.513610, Expected=257.408081
# Time_value=1146, Predicted=444.049817, Expected=258.002625
# Time_value=1147, Predicted=443.813475, Expected=257.873810
# Time_value=1148, Predicted=444.347410, Expected=260.489899
# Time_value=1149, Predicted=444.214261, Expected=260.331329
# Time_value=1150, Predicted=446.607361, Expected=262.610535
# Time_value=1151, Predicted=446.417867, Expected=262.065491
# Time_value=1152, Predicted=448.480082, Expected=261.748413
# Time_value=1153, Predicted=447.931956, Expected=260.807007
# Time_value=1154, Predicted=447.621343, Expected=260.856567
# Time_value=1155, Predicted=446.753780, Expected=261.679047
# Time_value=1156, Predicted=446.809705, Expected=263.106018
# Time_value=1157, Predicted=447.566637, Expected=263.898743
# Time_value=1158, Predicted=448.858962, Expected=264.364502
# Time_value=1159, Predicted=449.551622, Expected=264.334778
# Time_value=1160, Predicted=449.945374, Expected=263.254639
# Time_value=1161, Predicted=449.892654, Expected=265.446869
# Time_value=1162, Predicted=448.892420, Expected=267.130127
# Time_value=1163, Predicted=450.902751, Expected=266.104248
# Time_value=1164, Predicted=452.402439, Expected=265.964783
# Time_value=1165, Predicted=451.416923, Expected=266.512573
# Time_value=1166, Predicted=451.280179, Expected=266.442871
# Time_value=1167, Predicted=451.776303, Expected=266.124146
# Time_value=1168, Predicted=451.699566, Expected=266.253632
# Time_value=1169, Predicted=451.402160, Expected=266.801422
# Time_value=1170, Predicted=451.521653, Expected=265.795441
# Time_value=1171, Predicted=452.018439, Expected=267.697845
# Time_value=1172, Predicted=451.090591, Expected=269.391083
# Time_value=1173, Predicted=452.834078, Expected=270.526520
# Time_value=1174, Predicted=454.344798, Expected=272.329315
# Time_value=1175, Predicted=455.326387, Expected=272.827332
# Time_value=1176, Predicted=456.912032, Expected=273.444855
# Time_value=1177, Predicted=457.299040, Expected=273.026489
# Time_value=1178, Predicted=457.810796, Expected=275.018524
# Time_value=1179, Predicted=457.390954, Expected=276.811371
# Time_value=1180, Predicted=459.177806, Expected=275.865143
# Time_value=1181, Predicted=460.746036, Expected=278.494598
# Time_value=1182, Predicted=459.820155, Expected=278.026489
# Time_value=1183, Predicted=462.175019, Expected=279.291412
# Time_value=1184, Predicted=461.681818, Expected=281.562317
# Time_value=1185, Predicted=462.790827, Expected=282.159943
# Time_value=1186, Predicted=464.790532, Expected=282.050354
# Time_value=1187, Predicted=465.247514, Expected=282.169861
# Time_value=1188, Predicted=465.086540, Expected=285.436798
# Time_value=1189, Predicted=465.159125, Expected=283.544373
# Time_value=1190, Predicted=468.073445, Expected=280.636047
# Time_value=1191, Predicted=466.276484, Expected=280.775452
# Time_value=1192, Predicted=463.645823, Expected=280.456726
# Time_value=1193, Predicted=463.831502, Expected=274.351227
# Time_value=1194, Predicted=463.572528, Expected=262.877136
# Time_value=1195, Predicted=458.083488, Expected=268.056427
# Time_value=1196, Predicted=447.819014, Expected=266.602264
# Time_value=1197, Predicted=452.847683, Expected=256.602295
# Time_value=1198, Predicted=451.604687, Expected=260.456848
# Time_value=1199, Predicted=442.537519, Expected=264.281525
# Time_value=1200, Predicted=446.287292, Expected=264.938904
# Time_value=1201, Predicted=449.847566, Expected=268.514587
# Time_value=1202, Predicted=450.414845, Expected=271.940857
# Time_value=1203, Predicted=453.645838, Expected=272.020508
# Time_value=1204, Predicted=456.682131, Expected=270.317352
# Time_value=1205, Predicted=456.645906, Expected=268.972717
# Time_value=1206, Predicted=455.038927, Expected=269.321350
# Time_value=1207, Predicted=453.816835, Expected=273.614136
# Time_value=1208, Predicted=454.156957, Expected=276.791412
# Time_value=1209, Predicted=458.054021, Expected=273.335266
# Time_value=1210, Predicted=460.842673, Expected=270.566345
# Time_value=1211, Predicted=457.599335, Expected=266.632141
# Time_value=1212, Predicted=455.097417, Expected=268.006592
# Time_value=1213, Predicted=451.583818, Expected=271.104218
# Time_value=1214, Predicted=452.940694, Expected=271.791473
# Time_value=1215, Predicted=455.785653, Expected=271.691864
# Time_value=1216, Predicted=456.364823, Expected=273.006592
# Time_value=1217, Predicted=456.237876, Expected=277.757568
# Time_value=1218, Predicted=457.413191, Expected=277.408936
# Time_value=1219, Predicted=461.674989, Expected=275.616150
# Time_value=1220, Predicted=461.237928, Expected=274.201782
# Time_value=1221, Predicted=459.555020, Expected=273.902985
# Time_value=1222, Predicted=458.278747, Expected=274.200012
# Time_value=1223, Predicted=458.037182, Expected=270.489990
# Time_value=1224, Predicted=458.325706, Expected=270.950012
# Time_value=1225, Predicted=454.968149, Expected=270.429993
# Time_value=1226, Predicted=455.463897, Expected=263.670013
# Time_value=1227, Predicted=455.027988, Expected=258.049988
# Time_value=1228, Predicted=448.909781, Expected=265.109985
# Time_value=1229, Predicted=443.917475, Expected=260.600006
# Time_value=1230, Predicted=450.549911, Expected=259.829987
# Time_value=1231, Predicted=446.411060, Expected=263.149994
# Time_value=1232, Predicted=445.769560, Expected=257.470001
# Time_value=1233, Predicted=448.862618, Expected=260.769989
# Time_value=1234, Predicted=443.637740, Expected=263.559998
# Time_value=1235, Predicted=446.741847, Expected=265.640015
# Time_value=1236, Predicted=449.290514, Expected=259.720001
# Time_value=1237, Predicted=451.136951, Expected=261.000000
# Time_value=1238, Predicted=445.664196, Expected=265.149994
# Time_value=1239, Predicted=446.902544, Expected=263.760010
# Time_value=1240, Predicted=450.712708, Expected=265.929993
# Time_value=1241, Predicted=449.379812, Expected=265.149994
# Time_value=1242, Predicted=451.346887, Expected=267.329987
# Time_value=1243, Predicted=450.593160, Expected=270.190002
# Time_value=1244, Predicted=452.567106, Expected=270.390015
# Time_value=1245, Predicted=455.120994, Expected=268.890015
# Time_value=1246, Predicted=455.220093, Expected=266.609985
# Time_value=1247, Predicted=453.806679, Expected=266.570007
# Time_value=1248, Predicted=451.733186, Expected=262.980011
# Time_value=1249, Predicted=451.738208, Expected=263.630005
# Time_value=1250, Predicted=448.487523, Expected=266.309998
# Time_value=1251, Predicted=449.155697, Expected=266.559998
# Time_value=1252, Predicted=451.630406, Expected=264.510010
# Time_value=1253, Predicted=451.826168, Expected=264.980011
# Time_value=1254, Predicted=449.936717, Expected=263.200012
# Time_value=1255, Predicted=450.392686, Expected=262.619995
# Time_value=1256, Predicted=448.776377, Expected=266.019989
# Time_value=1257, Predicted=448.281046, Expected=266.920013
# Time_value=1258, Predicted=451.413138, Expected=266.920013
# Time_value=1259, Predicted=452.189215, Expected=269.500000
# Time_value=1260, Predicted=452.147844, Expected=272.019989
# Time_value=1261, Predicted=454.472852, Expected=272.850006
# Time_value=1262, Predicted=456.699214, Expected=272.980011
# Time_value=1263, Predicted=457.366116, Expected=271.100006
# Time_value=1264, Predicted=457.418304, Expected=272.239990
# Time_value=1265, Predicted=455.673132, Expected=272.010010
# Time_value=1266, Predicted=456.719561, Expected=271.329987
# Time_value=1267, Predicted=456.492900, Expected=273.369995
# Time_value=1268, Predicted=455.868057, Expected=272.609985
# Time_value=1269, Predicted=457.725475, Expected=273.359985
# Time_value=1270, Predicted=456.999326, Expected=272.799988
# Time_value=1271, Predicted=457.672085, Expected=272.149994
# Time_value=1272, Predicted=457.146115, Expected=269.019989
# Time_value=1273, Predicted=456.557068, Expected=272.609985
# Time_value=1274, Predicted=453.730793, Expected=270.940002
# Time_value=1275, Predicted=457.056853, Expected=273.600006
# Time_value=1276, Predicted=455.509845, Expected=274.899994
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-101-d3bdcfb25497> in <module>()
#      11     # store forecast
#      12     predictions.append(yhat)
# ---> 13     expected = adj_close_data.values[len(train) + i + 1]
#      14     print('Time_value=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
#
# IndexError: index 6383 is out of bounds for axis 0 with size 6383

# %%
isinstance(adj_close_data, pd.Series)
# Out:
# True

# %% [markdown]
# ## Initial random noise for GAN

# %%
# noise
# adj_close_data + 0.5(+-random.uniform(0.05*adj_close_data))

# %%
x, cols = generateData(nObs=520,size0=5,size1=5,mu0=0,sigma0=1e-2,sigma1F=.25,sLength=260)

# %%
x + np.random.uniform()
# Out:
# array([[-0.0135472 , -0.0007816 , -0.00953293, ..., -0.01239322,
#         -0.00785447, -0.00047046],
#        [ 0.00646519, -0.00362034,  0.00514823, ..., -0.00889116,
#         -0.00894014, -0.00513731],
#        [-0.0011967 ,  0.00353195, -0.0020002 , ..., -0.0185029 ,
#         -0.00752751,  0.00506009],
#        ...,
#        [-0.00022572,  0.01555214,  0.00742646, ...,  0.01431497,
#          0.01124302,  0.01753849],
#        [-0.00799441,  0.00563538, -0.00464556, ..., -0.00962632,
#         -0.00766688,  0.00182281],
#        [ 0.00579761,  0.01643316, -0.00325538, ..., -0.00161548,
#         -0.00185555,  0.01483365]])

# %% [markdown]
# ## GAN for finance implementation

# %%
from keras.layers import Input, Reshape

# %%
noise = np.random.normal(0, 1, (32, 1, 1))
print(noise.dtype, noise.shape)
model.predict(noise, batch_size=1).shape
# Out:
# float64 (32, 1, 1)
# (32, 1)

# %%
shitmodel = Sequential()

shitmodel.add(LSTM(4, batch_input_shape=(1, 1, 1), stateful=True))
shitmodel.add(Dense(1))
#shitmodel.add(Reshape((1, 1, 1)))
shitmodel.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_15 (LSTM)               (1, 4)                    96
# _________________________________________________________________
# dense_15 (Dense)             (1, 1)                    5
# =================================================================
# Total params: 101
# Trainable params: 101
# Non-trainable params: 0
# _________________________________________________________________

# %%
z = Input(shape=(1, 1,))
noise_datum = shitmodel(z)
shitmodel.reset_states()

# %%
noise = np.random.normal(0, 1, (32, 1, 1,))
print(noise.dtype, noise.shape)
shitmodel.predict(noise, batch_size=1).shape
# Out:
# float64 (32, 1, 1)
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-188-e80f7c26425a> in <module>()
#       1 noise = np.random.normal(0, 1, (32, 1, 1,))
#       2 print(noise.dtype, noise.shape)
# ----> 3 shitmodel.predict(noise, batch_size=1).shape
#
# ~/deepenv/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1170                                             batch_size=batch_size,
#    1171                                             verbose=verbose,
# -> 1172                                             steps=steps)
#    1173
#    1174     def train_on_batch(self, x, y,
#
# ~/deepenv/lib/python3.6/site-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     295                 ins_batch[i] = ins_batch[i].toarray()
#     296
# --> 297             batch_outs = f(ins_batch)
#     298             if not isinstance(batch_outs, list):
#     299                 batch_outs = [batch_outs]
#
# ~/deepenv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2659                 return self._legacy_call(inputs)
#    2660
# -> 2661             return self._call(inputs)
#    2662         else:
#    2663             if py_any(is_tensor(x) for x in inputs):
#
# ~/deepenv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2629                                 symbol_vals,
#    2630                                 session)
# -> 2631         fetched = self._callable_fn(*array_vals)
#    2632         return fetched[:len(self.outputs)]
#    2633
#
# ~/deepenv/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args)
#    1452         else:
#    1453           return tf_session.TF_DeprecatedSessionRunCallable(
# -> 1454               self._session._session, self._handle, args, status, None)
#    1455
#    1456     def __del__(self):
#
# ~/deepenv/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     517             None, None,
#     518             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 519             c_api.TF_GetCode(self.status.status))
#     520     # Delete the underlying status object from memory otherwise it stays alive
#     521     # as there is a reference to status from this from the traceback due to
#
# InvalidArgumentError: You must feed a value for placeholder tensor 'input_14' with dtype float and shape [?,1,1]
# 	 [[Node: input_14 = Placeholder[dtype=DT_FLOAT, shape=[?,1,1], _device="/job:localhost/replica:0/task:0/device:GPU:0"]()]]
# 	 [[Node: dense_15/BiasAdd/_847 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device="/job:localhost/replica:0/task:0/device:GPU:0", send_device_incarnation=1, tensor_name="edge_396_dense_15/BiasAdd", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:CPU:0"]()]]
